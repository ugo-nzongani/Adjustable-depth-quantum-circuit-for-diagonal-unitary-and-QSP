# %%
from qsp import *

# %%
def f(x):
    return np.exp(-(x-1/2)**2)+x

# %%
n = 3
m = 0
p = 0

qc = adjustable_depth_diagonal_controlled(n,m,p,f)

qc.draw('mpl')
# Out:
# Adjustable-depth(n=3,m=0,p=2)
